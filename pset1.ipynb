# %%
import numpy as numpy
import matplotlib.pyplot as plt

# %%
def density_prof(r, rho_c, R):
    return rho_c * (1 - (r/R)**2)

# get the integral numerically, for enclosed mass
def enclosed_mass(r, rho_c, R):
    return 4 * numpy.pi * rho_c * (r**3/3 - r**5/(5*R**2))

r = numpy.linspace(0, 1, 100)
rho_c = 1
R = 1
rho = density_prof(r, rho_c, R)
m_enc = enclosed_mass(r, rho_c, R)
fig, ax = plt.subplots(2,1, dpi=300, figsize=(6,4))
ax[0].plot(r, rho)
ax[1].plot(r, m_enc)
ax[0].set_ylabel(r'$\rho$')
ax[1].set_ylabel(r'$M_{\rm enc}$')
ax[1].set_xlabel('r')
# Out:
# Text(0.5, 0, 'r')
